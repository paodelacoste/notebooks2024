# %% [markdown]
# # Aula 12 - utilização do visual studio

# %% [markdown]
# #### Laboratorio 01 - Detect faces in Vision Studio
#
# - nesse laboratorio aprendi a usar o vision studios para detectar faces entre outros filtros como por exemplo para recortar o fundo das imagens.
#
# - se não houver nenhum obstaculo ele consegue detectar varios detalhes como por exemplo se a pessoa esta utilizando mascara ou não e entre outros aspectos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Laboratorio 02 - Read text in Vision Studio
#
# - Nesse laboratorio é mostrado a função de detecção de texto no vision studio
#
# ![image.png](attachment:image.png)
#
# - Aqui você pode selecionar e separar textos em uma imagem!

# %% [markdown]
# ### Laboratorio 03 - Analyze images in Vision Studio
#
# -  Aqui temos um trabalho muito proximo ao do laboratorio 01, todavia é mais detalhado
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# - Agora além de rostos ele detecta também objetos do ambiente
